# %% [markdown]
# <a href="https://colab.research.google.com/github/al-imran-sonet/Learning_PyTorch/blob/main/PyTorch01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Rendom tensors
#
# Why random tensors?
#
# Neural network start working using tensors with rendom numbers initialy .Then step by step it changes the random number for better representation
#
# The flow is
#
# 1.starts with random number
#
# 2.look at data
#
# 3.update random number
#
# 4.look at data
#
# 5.again step 3
#
# -->>read_about{torch.rand()}

# %%
import torch

# %%
#create a random tensor size of(3,4)
import torch
random_tensor=torch.rand(4,10,3,4) #torch.rand(size(4,10,3,4))
random_tensor
# Out:
# tensor([[[[0.2016, 0.4376, 0.5353, 0.0561],
#           [0.3507, 0.4199, 0.2577, 0.5839],
#           [0.9741, 0.1021, 0.8972, 0.0690]],
#
#          [[0.6509, 0.7667, 0.3269, 0.5174],
#           [0.4390, 0.8451, 0.1940, 0.2243],
#           [0.5135, 0.6600, 0.9154, 0.1685]],
#
#          [[0.9675, 0.6298, 0.8931, 0.7049],
#           [0.9196, 0.2423, 0.2014, 0.4682],
#           [0.4426, 0.1026, 0.9229, 0.4216]],
#
#          [[0.1530, 0.8857, 0.9752, 0.5608],
#           [0.2654, 0.3970, 0.7242, 0.9188],
#           [0.3184, 0.5726, 0.0222, 0.1516]],
#
#          [[0.1333, 0.2881, 0.4524, 0.8001],
#           [0.7190, 0.4612, 0.2964, 0.3037],
#           [0.0381, 0.7155, 0.2199, 0.4387]],
#
#          [[0.4421, 0.3055, 0.1579, 0.0529],
#           [0.4745, 0.2571, 0.7626, 0.4568],
#           [0.1850, 0.9629, 0.3598, 0.7767]],
#
#          [[0.6367, 0.8814, 0.0410, 0.5674],
#           [0.2555, 0.7676, 0.2536, 0.0186],
#           [0.2607, 0.2898, 0.7920, 0.2754]],
#
# ...

# %%
random_tensor.ndim
# Out:
# 4

# %%
random_tensor.shape
# Out:
# torch.Size([4, 10, 3, 4])

# %%
#creat a random tensor with similar shape to an image tensor
random_image_size_tensor= torch.rand(size=(3,224,224)) #  colour channals(R,G,B), height, width
random_image_size_tensor
# Out:
# tensor([[[0.2035, 0.1831, 0.8495,  ..., 0.7564, 0.7595, 0.4700],
#          [0.0792, 0.1116, 0.2437,  ..., 0.1936, 0.2832, 0.4308],
#          [0.6279, 0.6815, 0.2234,  ..., 0.9488, 0.4457, 0.7971],
#          ...,
#          [0.3483, 0.9608, 0.5296,  ..., 0.7404, 0.2798, 0.8646],
#          [0.8272, 0.0282, 0.4072,  ..., 0.2091, 0.9728, 0.8781],
#          [0.5474, 0.9294, 0.7710,  ..., 0.3004, 0.3724, 0.3851]],
#
#         [[0.2612, 0.1101, 0.2221,  ..., 0.6422, 0.6031, 0.6172],
#          [0.8503, 0.0958, 0.0313,  ..., 0.9428, 0.1316, 0.2362],
#          [0.8262, 0.9981, 0.5372,  ..., 0.7048, 0.1069, 0.3064],
#          ...,
#          [0.5832, 0.3005, 0.0972,  ..., 0.4918, 0.8396, 0.9539],
#          [0.7396, 0.2740, 0.1555,  ..., 0.4963, 0.9118, 0.2949],
#          [0.7016, 0.6105, 0.1257,  ..., 0.5968, 0.5388, 0.2083]],
#
#         [[0.7997, 0.1534, 0.0370,  ..., 0.7468, 0.8144, 0.2291],
#          [0.4547, 0.6967, 0.7905,  ..., 0.7241, 0.2138, 0.6642],
# ...

# %%
random_image_size_tensor.shape,random_image_size_tensor.ndim
# Out:
# (torch.Size([3, 224, 224]), 3)
